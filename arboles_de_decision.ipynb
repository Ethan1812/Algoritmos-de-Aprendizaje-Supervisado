# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x = "fixed acidity", y = "residual sugar", hue = "quality", data = data)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='residual sugar'>

# %%
predictors_col = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar"]
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar
# 0               7.4             0.700         0.00             1.9
# 1               7.8             0.880         0.00             2.6
# 2               7.8             0.760         0.04             2.3
# 3              11.2             0.280         0.56             1.9
# 4               7.4             0.700         0.00             1.9
# ...             ...               ...          ...             ...
# 1594            6.2             0.600         0.08             2.0
# 1595            5.9             0.550         0.10             2.2
# 1596            6.3             0.510         0.13             2.3
# 1597            5.9             0.645         0.12             2.0
# 1598            6.0             0.310         0.47             3.6
#
# [1599 rows x 4 columns]

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
corr = predictors.corr()
corr
# Out:
#                   fixed acidity  volatile acidity  citric acid  residual sugar
# fixed acidity          1.000000         -0.256131     0.671703        0.114777
# volatile acidity      -0.256131          1.000000    -0.552496        0.001918
# citric acid            0.671703         -0.552496     1.000000        0.143577
# residual sugar         0.114777          0.001918     0.143577        1.000000

# %%
sns.heatmap(corr)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.25, random_state=13)

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.5179759635562395, 0.9782608695652174, 'x[1] <= 0.548\ngini = 0.644\nsamples = 1199\nvalue = [8, 42, 500, 487, 150, 12]'),
#  Text(0.21563614822327923, 0.9347826086956522, 'x[1] <= 0.317\ngini = 0.647\nsamples = 656\nvalue = [1, 13, 198, 312, 122, 10]'),
#  Text(0.06141578063794068, 0.8913043478260869, 'x[1] <= 0.275\ngini = 0.601\nsamples = 133\nvalue = [0, 1, 14, 66, 50, 2]'),
#  Text(0.029099048684946838, 0.8478260869565217, 'x[0] <= 8.35\ngini = 0.56\nsamples = 67\nvalue = [0, 1, 7, 40, 18, 1]'),
#  Text(0.013430330162283156, 0.8043478260869565, 'x[2] <= 0.235\ngini = 0.318\nsamples = 27\nvalue = [0, 0, 3, 22, 2, 0]'),
#  Text(0.01119194180190263, 0.7608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.01566871852266368, 0.7608695652173914, 'x[1] <= 0.265\ngini = 0.272\nsamples = 26\nvalue = [0, 0, 2, 22, 2, 0]'),
#  Text(0.01119194180190263, 0.717391304347826, 'x[2] <= 0.41\ngini = 0.226\nsamples = 24\nvalue = [0, 0, 2, 21, 1, 0]'),
#  Text(0.008953553441522105, 0.6739130434782609, 'x[2] <= 0.385\ngini = 0.338\nsamples = 15\nvalue = [0, 0, 2, 12, 1, 0]'),
#  Text(0.004476776720761052, 0.6304347826086957, 'x[3] <= 2.25\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.002238388360380526, 0.5869565217391305, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.006715165081141578, 0.5869565217391305, 'x[1] <= 0.25\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.004476776720761052, 0.5434782608695652, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.008953553441522105, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.013430330162283156, 0.6304347826086957, 'x[1] <= 0.195\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.01119194180190263, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.01566871852266368, 0.5869565217391305, 'x[1] <= 0.22\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.013430330162283156, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.01790710688304421, 0.5434782608695652, 'x[1] <= 0.235\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.01566871852266368, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.020145495243424735, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.013430330162283156, 0.6739130434782609, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.020145495243424735, 0.717391304347826, 'x[2] <= 0.47\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.01790710688304421, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.02238388360380526, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04476776720761052, 0.8043478260869565, 'x[2] <= 0.335\ngini = 0.626\nsamples = 40\nvalue = [0, 1, 4, 18, 16, 1]'),
#  Text(0.042529378847229994, 0.7608695652173914, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.047006155567991044, 0.7608695652173914, 'x[2] <= 0.475\ngini = 0.637\nsamples = 36\nvalue = [0, 1, 4, 14, 16, 1]'),
#  Text(0.03469501958589815, 0.717391304347826, 'x[1] <= 0.255\ngini = 0.562\nsamples = 18\nvalue = [0, 1, 2, 4, 11, 0]'),
#  Text(0.026860660324566313, 0.6739130434782609, 'x[3] <= 1.75\ngini = 0.379\nsamples = 13\nvalue = [0, 1, 0, 2, 10, 0]'),
#  Text(0.02238388360380526, 0.6304347826086957, 'x[2] <= 0.38\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.020145495243424735, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.024622271964185788, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.03133743704532736, 0.6304347826086957, 'x[3] <= 2.15\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 0, 0, 9, 0]'),
#  Text(0.029099048684946838, 0.5869565217391305, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.03357582540570789, 0.5869565217391305, 'x[2] <= 0.405\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.03133743704532736, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.03581421376608842, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.042529378847229994, 0.6739130434782609, 'x[2] <= 0.46\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 2, 2, 1, 0]'),
#  Text(0.04029099048684947, 0.6304347826086957, 'x[2] <= 0.4\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.038052602126468944, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.042529378847229994, 0.5869565217391305, 'x[3] <= 3.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.04029099048684947, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.04476776720761052, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04476776720761052, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.05931729155008394, 0.717391304347826, 'x[0] <= 10.05\ngini = 0.599\nsamples = 18\nvalue = [0, 0, 2, 10, 5, 1]'),
#  Text(0.0514829322887521, 0.6739130434782609, 'x[1] <= 0.265\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 0, 2, 4, 1]'),
#  Text(0.049244543928371576, 0.6304347826086957, 'x[2] <= 0.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1]'),
#  Text(0.047006155567991044, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.0514829322887521, 0.5869565217391305, 'x[0] <= 9.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.049244543928371576, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.053721320649132626, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.053721320649132626, 0.6304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.06715165081141578, 0.6739130434782609, 'x[2] <= 0.65\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 2, 8, 1, 0]'),
#  Text(0.06491326245103525, 0.6304347826086957, 'x[0] <= 10.3\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 1, 8, 1, 0]'),
#  Text(0.0604364857302742, 0.5869565217391305, 'x[2] <= 0.515\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.058198097369893675, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06267487409065473, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0693900391717963, 0.5869565217391305, 'x[0] <= 11.7\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.06715165081141578, 0.5434782608695652, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.07162842753217684, 0.5434782608695652, 'x[0] <= 12.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.0693900391717963, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.07386681589255736, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.0693900391717963, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09373251259093453, 0.8478260869565217, 'x[2] <= 0.37\ngini = 0.598\nsamples = 66\nvalue = [0, 0, 7, 26, 32, 1]'),
#  Text(0.08058198097369894, 0.8043478260869565, 'x[3] <= 2.55\ngini = 0.379\nsamples = 13\nvalue = [0, 0, 1, 2, 10, 0]'),
#  Text(0.07610520425293789, 0.7608695652173914, 'x[3] <= 1.95\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 1, 10, 0]'),
#  Text(0.07386681589255736, 0.717391304347826, 'x[3] <= 1.8\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.07162842753217684, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.07610520425293789, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07834359261331841, 0.717391304347826, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.08505875769445999, 0.7608695652173914, 'x[0] <= 8.65\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.08282036933407946, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08729714605484051, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10688304420817012, 0.8043478260869565, 'x[0] <= 7.75\ngini = 0.609\nsamples = 53\nvalue = [0, 0, 6, 24, 22, 1]'),
#  Text(0.10464465584778959, 0.7608695652173914, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.10912143256855064, 0.7608695652173914, 'x[0] <= 8.55\ngini = 0.617\nsamples = 46\nvalue = [0, 0, 6, 17, 22, 1]'),
#  Text(0.09177392277560156, 0.717391304347826, 'x[3] <= 1.75\ngini = 0.477\nsamples = 16\nvalue = [0, 0, 3, 2, 11, 0]'),
#  Text(0.08729714605484051, 0.6739130434782609, 'x[3] <= 1.65\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.08505875769445999, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08953553441522104, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09625069949636261, 0.6739130434782609, 'x[1] <= 0.295\ngini = 0.357\nsamples = 14\nvalue = [0, 0, 2, 1, 11, 0]'),
#  Text(0.09401231113598209, 0.6304347826086957, 'x[0] <= 8.1\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 2, 1, 5, 0]'),
#  Text(0.08953553441522104, 0.5869565217391305, 'x[2] <= 0.465\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.08729714605484051, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09177392277560156, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.09848908785674315, 0.5869565217391305, 'x[3] <= 2.7\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 0, 5, 0]'),
#  Text(0.09625069949636261, 0.5434782608695652, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.10072747621712368, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09848908785674315, 0.6304347826086957, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.12646894236149972, 0.717391304347826, 'x[3] <= 2.5\ngini = 0.604\nsamples = 30\nvalue = [0, 0, 3, 15, 11, 1]'),
#  Text(0.11639619473978735, 0.6739130434782609, 'x[0] <= 10.8\ngini = 0.472\nsamples = 21\nvalue = [0, 0, 1, 14, 6, 0]'),
#  Text(0.1119194180190263, 0.6304347826086957, 'x[3] <= 2.1\ngini = 0.379\nsamples = 13\nvalue = [0, 0, 1, 10, 2, 0]'),
#  Text(0.10968102965864578, 0.5869565217391305, 'x[0] <= 9.4\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 4, 2, 0]'),
#  Text(0.10520425293788473, 0.5434782608695652, 'x[0] <= 8.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.1029658645775042, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10744264129826525, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.11415780637940683, 0.5434782608695652, 'x[2] <= 0.395\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.1119194180190263, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.11639619473978735, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.11415780637940683, 0.5869565217391305, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.1208729714605484, 0.6304347826086957, 'x[1] <= 0.29\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.11863458310016788, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.12311135982092893, 0.5869565217391305, 'x[0] <= 11.3\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.1208729714605484, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.12534974818130945, 0.5434782608695652, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.1365416899832121, 0.6739130434782609, 'x[0] <= 10.75\ngini = 0.617\nsamples = 9\nvalue = [0, 0, 2, 1, 5, 1]'),
#  Text(0.13430330162283155, 0.6304347826086957, 'x[0] <= 9.7\ngini = 0.72\nsamples = 5\nvalue = [0, 0, 2, 1, 1, 1]'),
#  Text(0.13206491326245104, 0.5869565217391305, 'x[2] <= 0.43\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 0, 1, 1, 1]'),
#  Text(0.1298265249020705, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.13430330162283155, 0.5434782608695652, 'x[0] <= 9.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.13206491326245104, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1365416899832121, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.1365416899832121, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1387800783435926, 0.6304347826086957, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.3698565158086178, 0.8913043478260869, 'x[3] <= 3.35\ngini = 0.635\nsamples = 523\nvalue = [1, 12, 184, 246, 72, 8]'),
#  Text(0.21229277420257414, 0.8478260869565217, 'x[3] <= 3.15\ngini = 0.614\nsamples = 456\nvalue = [1, 7, 162, 226, 53, 7]'),
#  Text(0.21005438584219363, 0.8043478260869565, 'x[0] <= 5.55\ngini = 0.619\nsamples = 446\nvalue = [1, 7, 162, 216, 53, 7]'),
#  Text(0.14773363178511473, 0.7608695652173914, 'x[1] <= 0.38\ngini = 0.698\nsamples = 13\nvalue = [0, 1, 1, 3, 6, 2]'),
#  Text(0.14325685506435368, 0.717391304347826, 'x[2] <= 0.125\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.14101846670397314, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1454952434247342, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.15221040850587578, 0.717391304347826, 'x[1] <= 0.515\ngini = 0.58\nsamples = 10\nvalue = [0, 1, 0, 1, 6, 2]'),
#  Text(0.14997202014549524, 0.6739130434782609, 'x[3] <= 2.25\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 1, 6, 2]'),
#  Text(0.14773363178511473, 0.6304347826086957, 'x[0] <= 5.45\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 0, 6, 2]'),
#  Text(0.1454952434247342, 0.5869565217391305, 'x[2] <= 0.21\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 0, 6, 1]'),
#  Text(0.14325685506435368, 0.5434782608695652, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.14773363178511473, 0.5434782608695652, 'x[2] <= 0.255\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.1454952434247342, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.14997202014549524, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.14997202014549524, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.15221040850587578, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1544487968662563, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.27237513989927253, 0.7608695652173914, 'x[2] <= 0.315\ngini = 0.608\nsamples = 433\nvalue = [1, 6, 161, 213, 47, 5]'),
#  Text(0.180732372691662, 0.717391304347826, 'x[3] <= 1.65\ngini = 0.55\nsamples = 200\nvalue = [0, 5, 79, 108, 7, 1]'),
#  Text(0.16116396194739788, 0.6739130434782609, 'x[3] <= 1.45\ngini = 0.375\nsamples = 16\nvalue = [0, 0, 12, 4, 0, 0]'),
#  Text(0.15668718522663683, 0.6304347826086957, 'x[0] <= 6.45\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.1544487968662563, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.15892557358701734, 0.5869565217391305, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.16564073866815893, 0.6304347826086957, 'x[2] <= 0.19\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]'),
#  Text(0.1634023503077784, 0.5869565217391305, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.16787912702853947, 0.5869565217391305, 'x[0] <= 7.2\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.16564073866815893, 0.5434782608695652, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.17011751538891998, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20030078343592614, 0.6739130434782609, 'x[2] <= 0.025\ngini = 0.546\nsamples = 184\nvalue = [0, 5, 67, 104, 7, 1]'),
#  Text(0.17459429210968103, 0.6304347826086957, 'x[3] <= 2.15\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 0, 10, 0, 0]'),
#  Text(0.17235590374930052, 0.5869565217391305, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.17683268047006157, 0.5869565217391305, 'x[0] <= 6.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.17459429210968103, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17907106883044208, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.22600727476217122, 0.6304347826086957, 'x[0] <= 5.8\ngini = 0.553\nsamples = 173\nvalue = [0, 4, 67, 94, 7, 1]'),
#  Text(0.2237688864017907, 0.5869565217391305, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.22824566312255176, 0.5869565217391305, 'x[0] <= 7.05\ngini = 0.549\nsamples = 169\nvalue = [0, 4, 63, 94, 7, 1]'),
#  Text(0.18354784555120313, 0.5434782608695652, 'x[1] <= 0.33\ngini = 0.468\nsamples = 50\nvalue = [0, 2, 13, 34, 1, 0]'),
#  Text(0.18130945719082261, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.18578623391158366, 0.5, 'x[1] <= 0.455\ngini = 0.444\nsamples = 48\nvalue = [0, 2, 11, 34, 1, 0]'),
#  Text(0.17039731393396754, 0.45652173913043476, 'x[3] <= 1.75\ngini = 0.27\nsamples = 20\nvalue = [0, 1, 1, 17, 1, 0]'),
#  Text(0.16815892557358703, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.17263570229434808, 0.41304347826086957, 'x[0] <= 6.15\ngini = 0.194\nsamples = 19\nvalue = [0, 1, 0, 17, 1, 0]'),
#  Text(0.16815892557358703, 0.3695652173913043, 'x[3] <= 1.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.1659205372132065, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.17039731393396754, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17711247901510913, 0.3695652173913043, 'x[3] <= 2.15\ngini = 0.111\nsamples = 17\nvalue = [0, 1, 0, 16, 0, 0]'),
#  Text(0.1748740906547286, 0.32608695652173914, 'x[3] <= 2.05\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.17263570229434808, 0.2826086956521739, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.17711247901510913, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.17935086737548964, 0.32608695652173914, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.20117515388919976, 0.45652173913043476, 'x[2] <= 0.245\ngini = 0.503\nsamples = 28\nvalue = [0, 1, 10, 17, 0, 0]'),
#  Text(0.19390039171796306, 0.41304347826086957, 'x[1] <= 0.485\ngini = 0.417\nsamples = 22\nvalue = [0, 1, 5, 16, 0, 0]'),
#  Text(0.18606603245663123, 0.3695652173913043, 'x[3] <= 1.75\ngini = 0.612\nsamples = 7\nvalue = [0, 1, 3, 3, 0, 0]'),
#  Text(0.1838276440962507, 0.32608695652173914, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.18830442081701176, 0.32608695652173914, 'x[2] <= 0.17\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.18606603245663123, 0.2826086956521739, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.19054280917739227, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2017347509792949, 0.3695652173913043, 'x[0] <= 6.95\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 2, 13, 0, 0]'),
#  Text(0.19725797425853386, 0.32608695652173914, 'x[1] <= 0.535\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 1, 12, 0, 0]'),
#  Text(0.19501958589815332, 0.2826086956521739, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.19949636261891437, 0.2826086956521739, 'x[2] <= 0.095\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.19725797425853386, 0.2391304347826087, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2017347509792949, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20621152770005596, 0.32608695652173914, 'x[3] <= 2.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.20397313933967542, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20844991606043647, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20844991606043647, 0.41304347826086957, 'x[2] <= 0.295\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.20621152770005596, 0.3695652173913043, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.210688304420817, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2729434806939004, 0.5434782608695652, 'x[1] <= 0.495\ngini = 0.566\nsamples = 119\nvalue = [0, 2, 50, 60, 6, 1]'),
#  Text(0.24790151091214327, 0.5, 'x[2] <= 0.295\ngini = 0.571\nsamples = 77\nvalue = [0, 1, 37, 34, 4, 1]'),
#  Text(0.23587017347509792, 0.45652173913043476, 'x[0] <= 9.4\ngini = 0.525\nsamples = 54\nvalue = [0, 1, 30, 22, 1, 0]'),
#  Text(0.2336317851147174, 0.41304347826086957, 'x[0] <= 8.7\ngini = 0.518\nsamples = 52\nvalue = [0, 1, 30, 20, 1, 0]'),
#  Text(0.23139339675433687, 0.3695652173913043, 'x[0] <= 7.95\ngini = 0.535\nsamples = 47\nvalue = [0, 1, 25, 20, 1, 0]'),
#  Text(0.2229994404029099, 0.32608695652173914, 'x[1] <= 0.395\ngini = 0.497\nsamples = 38\nvalue = [0, 1, 23, 14, 0, 0]'),
#  Text(0.21292669278119752, 0.2826086956521739, 'x[0] <= 7.25\ngini = 0.398\nsamples = 16\nvalue = [0, 1, 12, 3, 0, 0]'),
#  Text(0.20844991606043647, 0.2391304347826087, 'x[3] <= 2.25\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.20621152770005596, 0.1956521739130435, 'x[1] <= 0.345\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.20397313933967542, 0.15217391304347827, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.20844991606043647, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.210688304420817, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2174034695019586, 0.2391304347826087, 'x[2] <= 0.235\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 9, 0, 0, 0]'),
#  Text(0.21516508114157806, 0.1956521739130435, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.2196418578623391, 0.1956521739130435, 'x[0] <= 7.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.2174034695019586, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.22188024622271965, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23307218802462226, 0.2826086956521739, 'x[1] <= 0.42\ngini = 0.5\nsamples = 22\nvalue = [0, 0, 11, 11, 0, 0]'),
#  Text(0.23083379966424175, 0.2391304347826087, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.2353105763850028, 0.2391304347826087, 'x[2] <= 0.275\ngini = 0.488\nsamples = 19\nvalue = [0, 0, 11, 8, 0, 0]'),
#  Text(0.23307218802462226, 0.1956521739130435, 'x[2] <= 0.175\ngini = 0.5\nsamples = 16\nvalue = [0, 0, 8, 8, 0, 0]'),
#  Text(0.2263570229434807, 0.15217391304347827, 'x[1] <= 0.44\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.22411863458310016, 0.10869565217391304, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2285954113038612, 0.10869565217391304, 'x[3] <= 2.3\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2263570229434807, 0.06521739130434782, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23083379966424175, 0.06521739130434782, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.23978735310576385, 0.15217391304347827, 'x[3] <= 2.4\ngini = 0.463\nsamples = 11\nvalue = [0, 0, 4, 7, 0, 0]'),
#  Text(0.2375489647453833, 0.10869565217391304, 'x[1] <= 0.475\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.2353105763850028, 0.06521739130434782, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.23978735310576385, 0.06521739130434782, 'x[2] <= 0.265\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.2375489647453833, 0.021739130434782608, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.2420257414661444, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2420257414661444, 0.10869565217391304, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2375489647453833, 0.1956521739130435, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.23978735310576385, 0.32608695652173914, 'x[2] <= 0.235\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 2, 6, 1, 0]'),
#  Text(0.2375489647453833, 0.2826086956521739, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2420257414661444, 0.2826086956521739, 'x[3] <= 1.95\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 2, 2, 1, 0]'),
#  Text(0.23978735310576385, 0.2391304347826087, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2442641298265249, 0.2391304347826087, 'x[1] <= 0.425\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.2420257414661444, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.24650251818690544, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.23587017347509792, 0.3695652173913043, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.23810856183547846, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.25993284834918856, 0.45652173913043476, 'x[3] <= 2.05\ngini = 0.616\nsamples = 23\nvalue = [0, 0, 7, 12, 3, 1]'),
#  Text(0.25097929490766646, 0.41304347826086957, 'x[1] <= 0.37\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 1, 7, 0, 1]'),
#  Text(0.24650251818690544, 0.3695652173913043, 'x[0] <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1]'),
#  Text(0.2442641298265249, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.24874090654728595, 0.32608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.25545607162842754, 0.3695652173913043, 'x[3] <= 1.85\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.253217683268047, 0.32608695652173914, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2576944599888081, 0.32608695652173914, 'x[0] <= 8.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.25545607162842754, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.25993284834918856, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.26888640179071066, 0.41304347826086957, 'x[2] <= 0.305\ngini = 0.643\nsamples = 14\nvalue = [0, 0, 6, 5, 3, 0]'),
#  Text(0.26440962506994964, 0.3695652173913043, 'x[1] <= 0.42\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.2621712367095691, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2666480134303302, 0.32608695652173914, 'x[3] <= 2.9\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.26440962506994964, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.26888640179071066, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.27336317851147174, 0.3695652173913043, 'x[1] <= 0.385\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 4, 5, 1, 0]'),
#  Text(0.2711247901510912, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2756015668718523, 0.32608695652173914, 'x[3] <= 2.75\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 4, 5, 0, 0]'),
#  Text(0.27336317851147174, 0.2826086956521739, 'x[1] <= 0.455\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.2711247901510912, 0.2391304347826087, 'x[3] <= 2.35\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.26888640179071066, 0.1956521739130435, 'x[3] <= 2.2\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2666480134303302, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2711247901510912, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.27336317851147174, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2756015668718523, 0.2391304347826087, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2778399552322328, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.29798545047565755, 0.5, 'x[0] <= 9.05\ngini = 0.518\nsamples = 42\nvalue = [0, 1, 13, 26, 2, 0]'),
#  Text(0.2935086737548965, 0.45652173913043476, 'x[2] <= 0.035\ngini = 0.473\nsamples = 39\nvalue = [0, 0, 11, 26, 2, 0]'),
#  Text(0.29127028539451594, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.295747062115277, 0.41304347826086957, 'x[2] <= 0.255\ngini = 0.444\nsamples = 37\nvalue = [0, 0, 9, 26, 2, 0]'),
#  Text(0.2890318970341354, 0.3695652173913043, 'x[3] <= 2.95\ngini = 0.368\nsamples = 27\nvalue = [0, 0, 4, 21, 2, 0]'),
#  Text(0.2867935086737549, 0.32608695652173914, 'x[0] <= 8.55\ngini = 0.328\nsamples = 26\nvalue = [0, 0, 3, 21, 2, 0]'),
#  Text(0.28231673195299384, 0.2826086956521739, 'x[1] <= 0.515\ngini = 0.288\nsamples = 24\nvalue = [0, 0, 3, 20, 1, 0]'),
#  Text(0.2800783435926133, 0.2391304347826087, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.2845551203133744, 0.2391304347826087, 'x[0] <= 7.7\ngini = 0.364\nsamples = 18\nvalue = [0, 0, 3, 14, 1, 0]'),
#  Text(0.2800783435926133, 0.1956521739130435, 'x[2] <= 0.15\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 2, 5, 1, 0]'),
#  Text(0.2778399552322328, 0.15217391304347827, 'x[0] <= 7.55\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.2756015668718523, 0.10869565217391304, 'x[3] <= 1.95\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.27336317851147174, 0.06521739130434782, 'x[3] <= 1.8\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2711247901510912, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2756015668718523, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2778399552322328, 0.06521739130434782, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2800783435926133, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.28231673195299384, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2890318970341354, 0.1956521739130435, 'x[2] <= 0.245\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]'),
#  Text(0.2867935086737549, 0.15217391304347827, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.29127028539451594, 0.15217391304347827, 'x[3] <= 1.95\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.2890318970341354, 0.10869565217391304, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2935086737548965, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.29127028539451594, 0.2826086956521739, 'x[0] <= 8.8\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.2890318970341354, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2935086737548965, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29127028539451594, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3024622271964186, 0.3695652173913043, 'x[0] <= 7.75\ngini = 0.5\nsamples = 10\nvalue = [0, 0, 5, 5, 0, 0]'),
#  Text(0.29798545047565755, 0.32608695652173914, 'x[2] <= 0.285\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.295747062115277, 0.2826086956521739, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.30022383883603804, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.30693900391717965, 0.32608695652173914, 'x[1] <= 0.53\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.3047006155567991, 0.2826086956521739, 'x[1] <= 0.51\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3024622271964186, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.30693900391717965, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.30917739227756014, 0.2826086956521739, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3024622271964186, 0.45652173913043476, 'x[1] <= 0.515\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.30022383883603804, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3047006155567991, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.36401790710688303, 0.717391304347826, 'x[0] <= 7.35\ngini = 0.643\nsamples = 233\nvalue = [1, 1, 82, 105, 40, 4]'),
#  Text(0.31477336317851146, 0.6739130434782609, 'x[1] <= 0.375\ngini = 0.645\nsamples = 20\nvalue = [0, 0, 5, 6, 9, 0]'),
#  Text(0.30693900391717965, 0.6304347826086957, 'x[2] <= 0.465\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 2, 1, 8, 0]'),
#  Text(0.3024622271964186, 0.5869565217391305, 'x[3] <= 2.45\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 0, 8, 0]'),
#  Text(0.30022383883603804, 0.5434782608695652, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.3047006155567991, 0.5434782608695652, 'x[0] <= 7.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.3024622271964186, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.30693900391717965, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3114157806379407, 0.5869565217391305, 'x[2] <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.30917739227756014, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3136541689983212, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3226077224398433, 0.6304347826086957, 'x[2] <= 0.38\ngini = 0.568\nsamples = 9\nvalue = [0, 0, 3, 5, 1, 0]'),
#  Text(0.3203693340794628, 0.5869565217391305, 'x[1] <= 0.425\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 3, 1, 1, 0]'),
#  Text(0.31813094571908224, 0.5434782608695652, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3226077224398433, 0.5434782608695652, 'x[0] <= 7.15\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.3203693340794628, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.32484611080022385, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.32484611080022385, 0.5869565217391305, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4132624510352546, 0.6739130434782609, 'x[0] <= 10.05\ngini = 0.632\nsamples = 213\nvalue = [1, 1, 77, 99, 31, 4]'),
#  Text(0.3767487409065473, 0.6304347826086957, 'x[1] <= 0.385\ngini = 0.61\nsamples = 123\nvalue = [0, 1, 53, 54, 13, 2]'),
#  Text(0.35926133184107445, 0.5869565217391305, 'x[0] <= 9.65\ngini = 0.623\nsamples = 55\nvalue = [0, 1, 16, 28, 10, 0]'),
#  Text(0.3433128147733632, 0.5434782608695652, 'x[1] <= 0.335\ngini = 0.575\nsamples = 44\nvalue = [0, 1, 8, 26, 9, 0]'),
#  Text(0.3293228875209849, 0.5, 'x[3] <= 2.1\ngini = 0.653\nsamples = 12\nvalue = [0, 0, 3, 4, 5, 0]'),
#  Text(0.32484611080022385, 0.45652173913043476, 'x[0] <= 8.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3226077224398433, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3270844991606044, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.33379966424174595, 0.45652173913043476, 'x[2] <= 0.525\ngini = 0.568\nsamples = 9\nvalue = [0, 0, 1, 3, 5, 0]'),
#  Text(0.3315612758813654, 0.41304347826086957, 'x[0] <= 8.55\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 1, 5, 0]'),
#  Text(0.3270844991606044, 0.3695652173913043, 'x[3] <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.32484611080022385, 0.32608695652173914, 'x[0] <= 8.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.3226077224398433, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3270844991606044, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3293228875209849, 0.32608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3360380526021265, 0.3695652173913043, 'x[3] <= 2.4\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.33379966424174595, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.338276440962507, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3360380526021265, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.35730274202574147, 0.5, 'x[0] <= 9.35\ngini = 0.486\nsamples = 32\nvalue = [0, 1, 5, 22, 4, 0]'),
#  Text(0.3528259653049804, 0.45652173913043476, 'x[3] <= 2.8\ngini = 0.445\nsamples = 29\nvalue = [0, 1, 3, 21, 4, 0]'),
#  Text(0.3505875769445999, 0.41304347826086957, 'x[2] <= 0.435\ngini = 0.411\nsamples = 28\nvalue = [0, 1, 2, 21, 4, 0]'),
#  Text(0.3449916060436486, 0.3695652173913043, 'x[1] <= 0.375\ngini = 0.32\nsamples = 20\nvalue = [0, 0, 0, 16, 4, 0]'),
#  Text(0.34275321768326805, 0.32608695652173914, 'x[2] <= 0.335\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 0, 16, 3, 0]'),
#  Text(0.3405148293228875, 0.2826086956521739, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.3449916060436486, 0.2826086956521739, 'x[2] <= 0.365\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 0, 9, 3, 0]'),
#  Text(0.3405148293228875, 0.2391304347826087, 'x[3] <= 1.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.338276440962507, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.34275321768326805, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3494683827644096, 0.2391304347826087, 'x[1] <= 0.365\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 1, 0]'),
#  Text(0.3472299944040291, 0.1956521739130435, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.35170677112479015, 0.1956521739130435, 'x[0] <= 7.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.3494683827644096, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3539451594851707, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3472299944040291, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.35618354784555123, 0.3695652173913043, 'x[2] <= 0.5\ngini = 0.531\nsamples = 8\nvalue = [0, 1, 2, 5, 0, 0]'),
#  Text(0.3539451594851707, 0.32608695652173914, 'x[3] <= 1.85\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.35170677112479015, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.35618354784555123, 0.2826086956521739, 'x[2] <= 0.46\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.3539451594851707, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3584219362059317, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3584219362059317, 0.32608695652173914, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.35506435366536093, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3617795187465025, 0.45652173913043476, 'x[0] <= 9.55\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.359541130386122, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.36401790710688303, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37520984890878567, 0.5434782608695652, 'x[3] <= 2.05\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 8, 2, 1, 0]'),
#  Text(0.37297146054840513, 0.5, 'x[3] <= 1.8\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.37073307218802465, 0.45652173913043476, 'x[1] <= 0.365\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.3684946838276441, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.37297146054840513, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.37520984890878567, 0.45652173913043476, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3774482372691662, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.39423614997202017, 0.5869565217391305, 'x[2] <= 0.335\ngini = 0.555\nsamples = 68\nvalue = [0, 0, 37, 26, 3, 2]'),
#  Text(0.39199776161163963, 0.5434782608695652, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.39647453833240065, 0.5434782608695652, 'x[2] <= 0.62\ngini = 0.577\nsamples = 59\nvalue = [0, 0, 28, 26, 3, 2]'),
#  Text(0.39423614997202017, 0.5, 'x[2] <= 0.435\ngini = 0.582\nsamples = 54\nvalue = [0, 0, 23, 26, 3, 2]'),
#  Text(0.38416340235030777, 0.45652173913043476, 'x[2] <= 0.395\ngini = 0.565\nsamples = 26\nvalue = [0, 0, 8, 15, 1, 2]'),
#  Text(0.3774482372691662, 0.41304347826086957, 'x[1] <= 0.415\ngini = 0.636\nsamples = 18\nvalue = [0, 0, 7, 8, 1, 2]'),
#  Text(0.37520984890878567, 0.3695652173913043, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.37968662562954675, 0.3695652173913043, 'x[1] <= 0.53\ngini = 0.633\nsamples = 16\nvalue = [0, 0, 5, 8, 1, 2]'),
#  Text(0.3774482372691662, 0.32608695652173914, 'x[0] <= 9.7\ngini = 0.596\nsamples = 15\nvalue = [0, 0, 5, 8, 1, 1]'),
#  Text(0.37297146054840513, 0.2826086956521739, 'x[0] <= 9.2\ngini = 0.521\nsamples = 13\nvalue = [0, 0, 4, 8, 0, 1]'),
#  Text(0.37073307218802465, 0.2391304347826087, 'x[2] <= 0.345\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 4, 5, 0, 1]'),
#  Text(0.3684946838276441, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.37297146054840513, 0.1956521739130435, 'x[2] <= 0.385\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 4, 3, 0, 1]'),
#  Text(0.3684946838276441, 0.15217391304347827, 'x[1] <= 0.425\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.36625629546726357, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37073307218802465, 0.10869565217391304, 'x[3] <= 2.05\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.3684946838276441, 0.06521739130434782, 'x[2] <= 0.37\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.36625629546726357, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37073307218802465, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.37297146054840513, 0.06521739130434782, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3774482372691662, 0.15217391304347827, 'x[3] <= 2.2\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.37520984890878567, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.37968662562954675, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37520984890878567, 0.2391304347826087, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.38192501398992723, 0.2826086956521739, 'x[2] <= 0.36\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.37968662562954675, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.38416340235030777, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.38192501398992723, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.39087856743144933, 0.41304347826086957, 'x[1] <= 0.415\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.38864017907106885, 0.3695652173913043, 'x[0] <= 8.9\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.3864017907106883, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39087856743144933, 0.32608695652173914, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.39311695579182987, 0.3695652173913043, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4043088975937325, 0.45652173913043476, 'x[1] <= 0.535\ngini = 0.554\nsamples = 28\nvalue = [0, 0, 15, 11, 2, 0]'),
#  Text(0.40207050923335197, 0.41304347826086957, 'x[0] <= 9.55\ngini = 0.573\nsamples = 24\nvalue = [0, 0, 11, 11, 2, 0]'),
#  Text(0.39759373251259095, 0.3695652173913043, 'x[0] <= 9.25\ngini = 0.512\nsamples = 18\nvalue = [0, 0, 11, 6, 1, 0]'),
#  Text(0.3953553441522104, 0.32608695652173914, 'x[2] <= 0.46\ngini = 0.561\nsamples = 14\nvalue = [0, 0, 7, 6, 1, 0]'),
#  Text(0.39311695579182987, 0.2826086956521739, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.39759373251259095, 0.2826086956521739, 'x[1] <= 0.435\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 7, 3, 1, 0]'),
#  Text(0.39311695579182987, 0.2391304347826087, 'x[1] <= 0.41\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.39087856743144933, 0.1956521739130435, 'x[2] <= 0.495\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.38864017907106885, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39311695579182987, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3953553441522104, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.40207050923335197, 0.2391304347826087, 'x[1] <= 0.515\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.3998321208729715, 0.1956521739130435, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.4043088975937325, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3998321208729715, 0.32608695652173914, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.40654728595411305, 0.3695652173913043, 'x[0] <= 9.85\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.4043088975937325, 0.32608695652173914, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4087856743144936, 0.32608695652173914, 'x[2] <= 0.515\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.40654728595411305, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.41102406267487407, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.40654728595411305, 0.41304347826086957, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.3987129266927812, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.44977616116396196, 0.6304347826086957, 'x[0] <= 10.55\ngini = 0.638\nsamples = 90\nvalue = [1, 0, 24, 45, 18, 2]'),
#  Text(0.42445439283715725, 0.5869565217391305, 'x[0] <= 10.15\ngini = 0.573\nsamples = 25\nvalue = [1, 0, 1, 12, 11, 0]'),
#  Text(0.4222160044767767, 0.5434782608695652, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.4266927811975378, 0.5434782608695652, 'x[2] <= 0.51\ngini = 0.566\nsamples = 22\nvalue = [1, 0, 1, 12, 8, 0]'),
#  Text(0.4222160044767767, 0.5, 'x[3] <= 2.15\ngini = 0.439\nsamples = 14\nvalue = [1, 0, 0, 10, 3, 0]'),
#  Text(0.41997761611639617, 0.45652173913043476, 'x[1] <= 0.47\ngini = 0.612\nsamples = 7\nvalue = [1, 0, 0, 3, 3, 0]'),
#  Text(0.4177392277560157, 0.41304347826086957, 'x[3] <= 1.95\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 0, 1, 3, 0]'),
#  Text(0.41550083939563515, 0.3695652173913043, 'x[3] <= 1.7\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0]'),
#  Text(0.4132624510352546, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.4177392277560157, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.41997761611639617, 0.3695652173913043, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.4222160044767767, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.42445439283715725, 0.45652173913043476, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
# ...
#  Text(0.8312814773363179, 0.45652173913043476, 'x[3] <= 3.95\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 11, 3, 0, 0]'),
#  Text(0.8290430889759374, 0.41304347826086957, 'x[1] <= 0.68\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 1, 0, 0]'),
#  Text(0.8268047006155568, 0.3695652173913043, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8312814773363179, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8335198656966983, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8172915500839396, 0.5434782608695652, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.8240067151650812, 0.5869565217391305, 'x[2] <= 0.115\ngini = 0.42\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.8217683268047006, 0.5434782608695652, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8262451035254617, 0.5434782608695652, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8559037493005036, 0.6304347826086957, 'x[3] <= 1.55\ngini = 0.282\nsamples = 85\nvalue = [0, 2, 71, 12, 0, 0]'),
#  Text(0.8514269725797425, 0.5869565217391305, 'x[2] <= 0.205\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.849188584219362, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8536653609401231, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8603805260212647, 0.5869565217391305, 'x[3] <= 1.85\ngini = 0.235\nsamples = 82\nvalue = [0, 1, 71, 10, 0, 0]'),
#  Text(0.8581421376608842, 0.5434782608695652, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.8626189143816452, 0.5434782608695652, 'x[1] <= 0.695\ngini = 0.272\nsamples = 69\nvalue = [0, 1, 58, 10, 0, 0]'),
#  Text(0.8514269725797425, 0.5, 'x[0] <= 7.55\ngini = 0.215\nsamples = 50\nvalue = [0, 1, 44, 5, 0, 0]'),
#  Text(0.8424734191382205, 0.45652173913043476, 'x[2] <= 0.215\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 9, 3, 0, 0]'),
#  Text(0.8379966424174594, 0.41304347826086957, 'x[0] <= 7.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8357582540570789, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.84023503077784, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8469501958589816, 0.41304347826086957, 'x[0] <= 7.35\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.844711807498601, 0.3695652173913043, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.849188584219362, 0.3695652173913043, 'x[1] <= 0.605\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.8469501958589816, 0.32608695652173914, 'x[2] <= 0.23\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.844711807498601, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.849188584219362, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8514269725797425, 0.32608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8603805260212647, 0.45652173913043476, 'x[2] <= 0.225\ngini = 0.148\nsamples = 38\nvalue = [0, 1, 35, 2, 0, 0]'),
#  Text(0.8581421376608842, 0.41304347826086957, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(0.8626189143816452, 0.41304347826086957, 'x[0] <= 8.8\ngini = 0.226\nsamples = 24\nvalue = [0, 1, 21, 2, 0, 0]'),
#  Text(0.8603805260212647, 0.3695652173913043, 'x[0] <= 8.45\ngini = 0.379\nsamples = 13\nvalue = [0, 1, 10, 2, 0, 0]'),
#  Text(0.8581421376608842, 0.32608695652173914, 'x[1] <= 0.673\ngini = 0.292\nsamples = 12\nvalue = [0, 1, 10, 1, 0, 0]'),
#  Text(0.8536653609401231, 0.2826086956521739, 'x[3] <= 2.25\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]'),
#  Text(0.8514269725797425, 0.2391304347826087, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.8559037493005036, 0.2391304347826087, 'x[1] <= 0.575\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.8536653609401231, 0.1956521739130435, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8581421376608842, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8626189143816452, 0.2826086956521739, 'x[2] <= 0.245\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8603805260212647, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8648573027420258, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8626189143816452, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8648573027420258, 0.3695652173913043, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8738108561835478, 0.5, 'x[1] <= 0.707\ngini = 0.388\nsamples = 19\nvalue = [0, 0, 14, 5, 0, 0]'),
#  Text(0.8693340794627868, 0.45652173913043476, 'x[0] <= 8.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.8670956911024063, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8715724678231673, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8782876329043089, 0.45652173913043476, 'x[0] <= 9.4\ngini = 0.305\nsamples = 16\nvalue = [0, 0, 13, 3, 0, 0]'),
#  Text(0.8760492445439284, 0.41304347826086957, 'x[1] <= 0.728\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.8738108561835478, 0.3695652173913043, 'x[0] <= 8.05\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.8715724678231673, 0.32608695652173914, 'x[3] <= 5.3\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.8693340794627868, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8738108561835478, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8760492445439284, 0.32608695652173914, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.8782876329043089, 0.3695652173913043, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.8805260212646894, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9171796306659206, 0.6739130434782609, 'x[2] <= 0.335\ngini = 0.526\nsamples = 60\nvalue = [0, 3, 36, 20, 1, 0]'),
#  Text(0.9045886961387801, 0.6304347826086957, 'x[0] <= 8.75\ngini = 0.524\nsamples = 34\nvalue = [0, 1, 15, 18, 0, 0]'),
#  Text(0.8973139339675433, 0.5869565217391305, 'x[0] <= 7.85\ngini = 0.461\nsamples = 25\nvalue = [0, 0, 9, 16, 0, 0]'),
#  Text(0.8894795747062115, 0.5434782608695652, 'x[3] <= 2.05\ngini = 0.473\nsamples = 13\nvalue = [0, 0, 8, 5, 0, 0]'),
#  Text(0.8850027979854505, 0.5, 'x[1] <= 0.62\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.88276440962507, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.887241186345831, 0.45652173913043476, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8939563514269726, 0.5, 'x[0] <= 7.25\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 7, 2, 0, 0]'),
#  Text(0.891717963066592, 0.45652173913043476, 'x[0] <= 6.95\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.8894795747062115, 0.41304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8939563514269726, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8961947397873531, 0.45652173913043476, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9051482932288752, 0.5434782608695652, 'x[1] <= 0.6\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11, 0, 0]'),
#  Text(0.9029099048684947, 0.5, 'x[1] <= 0.585\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.9006715165081142, 0.45652173913043476, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9051482932288752, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9073866815892557, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.9118634583100168, 0.5869565217391305, 'x[3] <= 2.65\ngini = 0.494\nsamples = 9\nvalue = [0, 1, 6, 2, 0, 0]'),
#  Text(0.9096250699496362, 0.5434782608695652, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.9141018466703973, 0.5434782608695652, 'x[0] <= 9.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.9118634583100168, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9163402350307779, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.929770565193061, 0.6304347826086957, 'x[0] <= 9.75\ngini = 0.334\nsamples = 26\nvalue = [0, 2, 21, 2, 1, 0]'),
#  Text(0.9275321768326805, 0.5869565217391305, 'x[3] <= 2.15\ngini = 0.282\nsamples = 25\nvalue = [0, 2, 21, 2, 0, 0]'),
#  Text(0.9252937884722999, 0.5434782608695652, 'x[1] <= 0.6\ngini = 0.449\nsamples = 14\nvalue = [0, 2, 10, 2, 0, 0]'),
#  Text(0.9208170117515388, 0.5, 'x[2] <= 0.52\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9185786233911584, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9230554001119194, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.929770565193061, 0.5, 'x[0] <= 9.0\ngini = 0.292\nsamples = 12\nvalue = [0, 1, 10, 1, 0, 0]'),
#  Text(0.9275321768326805, 0.45652173913043476, 'x[2] <= 0.42\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 10, 0, 0, 0]'),
#  Text(0.9252937884722999, 0.41304347826086957, 'x[1] <= 0.66\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9230554001119194, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9275321768326805, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.929770565193061, 0.41304347826086957, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.9320089535534415, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.929770565193061, 0.5434782608695652, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.9320089535534415, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9261331841074426, 0.7608695652173914, 'x[3] <= 2.05\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.9238947957470621, 0.717391304347826, 'x[1] <= 0.835\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9216564073866816, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9261331841074426, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9283715724678232, 0.717391304347826, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9395635142697258, 0.8043478260869565, 'x[2] <= 0.13\ngini = 0.169\nsamples = 22\nvalue = [0, 1, 20, 0, 1, 0]'),
#  Text(0.9350867375489648, 0.7608695652173914, 'x[2] <= 0.11\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.9328483491885842, 0.717391304347826, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9373251259093452, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9440402909904868, 0.7608695652173914, 'x[2] <= 0.265\ngini = 0.105\nsamples = 18\nvalue = [0, 1, 17, 0, 0, 0]'),
#  Text(0.9418019026301063, 0.717391304347826, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.9462786793508674, 0.717391304347826, 'x[3] <= 2.2\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(0.9440402909904868, 0.6739130434782609, 'x[1] <= 1.078\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9418019026301063, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9462786793508674, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9485170677112479, 0.6739130434782609, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9753777280358142, 0.8478260869565217, 'x[1] <= 0.627\ngini = 0.621\nsamples = 37\nvalue = [0, 3, 12, 19, 2, 1]'),
#  Text(0.9630665920537214, 0.8043478260869565, 'x[2] <= 0.665\ngini = 0.494\nsamples = 21\nvalue = [0, 1, 5, 14, 0, 1]'),
#  Text(0.9608282036933408, 0.7608695652173914, 'x[0] <= 12.2\ngini = 0.445\nsamples = 20\nvalue = [0, 1, 5, 14, 0, 0]'),
#  Text(0.9552322327923894, 0.717391304347826, 'x[2] <= 0.225\ngini = 0.338\nsamples = 15\nvalue = [0, 1, 2, 12, 0, 0]'),
#  Text(0.952993844432009, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.95747062115277, 0.6739130434782609, 'x[2] <= 0.6\ngini = 0.255\nsamples = 14\nvalue = [0, 1, 1, 12, 0, 0]'),
#  Text(0.952993844432009, 0.6304347826086957, 'x[3] <= 2.15\ngini = 0.153\nsamples = 12\nvalue = [0, 1, 0, 11, 0, 0]'),
#  Text(0.9507554560716285, 0.5869565217391305, 'x[1] <= 0.585\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9485170677112479, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.952993844432009, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9552322327923894, 0.5869565217391305, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.961947397873531, 0.6304347826086957, 'x[1] <= 0.6\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9597090095131505, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9641857862339116, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9664241745942921, 0.717391304347826, 'x[2] <= 0.47\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.9641857862339116, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9686625629546727, 0.6739130434782609, 'x[3] <= 3.55\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.9664241745942921, 0.6304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9709009513150532, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9653049804141018, 0.7608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9876888640179071, 0.8043478260869565, 'x[2] <= 0.495\ngini = 0.68\nsamples = 16\nvalue = [0, 2, 7, 5, 2, 0]'),
#  Text(0.9798545047565753, 0.7608695652173914, 'x[2] <= 0.375\ngini = 0.542\nsamples = 12\nvalue = [0, 1, 7, 4, 0, 0]'),
#  Text(0.9753777280358142, 0.717391304347826, 'x[1] <= 0.68\ngini = 0.611\nsamples = 6\nvalue = [0, 1, 2, 3, 0, 0]'),
#  Text(0.9731393396754336, 0.6739130434782609, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9776161163961947, 0.6739130434782609, 'x[1] <= 0.912\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.9753777280358142, 0.6304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9798545047565753, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9843312814773363, 0.717391304347826, 'x[1] <= 0.875\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.9820928931169558, 0.6739130434782609, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9865696698377169, 0.6739130434782609, 'x[1] <= 1.022\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9843312814773363, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9888080581980974, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9955232232792389, 0.7608695652173914, 'x[3] <= 2.9\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 0, 1, 2, 0]'),
#  Text(0.9932848349188584, 0.717391304347826, 'x[1] <= 0.735\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9910464465584778, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9955232232792389, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9977616116396195, 0.717391304347826, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]')]

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([6, 5, 5, 5, 4, 5, 5, 6, 5, 5, 5, 6, 5, 5, 7, 7, 6, 7, 6, 5, 5, 6,
#        7, 5, 5, 5, 6, 5, 6, 6, 6, 7, 5, 6, 6, 5, 6, 6, 6, 6, 6, 7, 6, 6,
#        7, 7, 6, 7, 6, 6, 6, 4, 5, 5, 7, 5, 6, 7, 6, 5, 5, 6, 5, 7, 7, 7,
#        7, 6, 5, 5, 6, 6, 6, 7, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 6, 6, 5, 5,
#        5, 5, 6, 6, 6, 6, 5, 6, 6, 5, 6, 6, 5, 7, 6, 5, 5, 5, 6, 6, 5, 7,
#        6, 6, 7, 5, 7, 6, 7, 7, 4, 6, 6, 5, 6, 6, 6, 6, 5, 5, 6, 7, 6, 5,
#        6, 7, 6, 5, 7, 5, 6, 6, 5, 6, 6, 6, 5, 5, 5, 6, 4, 6, 5, 5, 6, 4,
#        5, 5, 6, 5, 6, 5, 6, 6, 6, 6, 6, 6, 6, 5, 6, 6, 5, 5, 5, 4, 5, 5,
#        5, 4, 5, 5, 5, 6, 6, 6, 5, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 7, 6,
#        5, 5, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6,
#        5, 5, 6, 6, 6, 6, 5, 5, 4, 6, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6,
#        5, 6, 5, 6, 7, 5, 5, 5, 6, 5, 5, 6, 6, 6, 7, 5, 5, 5, 5, 7, 7, 5,
#        6, 6, 6, 7, 5, 5, 6, 5, 6, 5, 6, 6, 6, 6, 5, 6, 5, 7, 6, 5, 5, 5,
#        5, 7, 5, 6, 5, 6, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 7, 5,
#        4, 6, 6, 6, 7, 6, 6, 5, 5, 5, 5, 6, 4, 5, 5, 6, 5, 5, 5, 7, 6, 6,
#        6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 7, 7, 5, 4, 4, 4, 6, 5, 5, 7,
#        6, 6, 6, 6, 5, 5, 7, 5, 7, 6, 7, 5, 5, 5, 5, 7, 6, 6, 6, 5, 5, 4,
#        6, 7, 6, 6, 5, 6, 6, 5, 6, 7, 6, 5, 5, 6, 5, 3, 7, 6, 7, 6, 6, 5,
#        6, 5, 6, 5], dtype=int64)

# %%
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  3  4    5   6   7
# Actual
# 3             0  1    1   0   0
# 4             1  1    4   5   0
# 5             0  6  108  57  10
# 6             0  6   38  96  11
# 7             0  0   12  12  25
# 8             0  0    2   2   2

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.575
